# %%
import getfem as gf
import numpy as np
import pyvista as pv

pv.start_xvfb()

# %%
X = np.linspace(0.0, 1000.0, 2 + 1)
Y = np.linspace(0.0, 1000.0, 2 + 1)
Z = np.linspace(0.0, 10000.0, 20 + 1)
mesh = gf.Mesh("cartesian", X, Y, Z)
mesh.export_to_vtk("mesh.vtk", "ascii")
m = pv.read("mesh.vtk")
m.plot(show_edges="True", jupyter_backend="static")
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F2384EF48E0>

# %%
elements_degree = 2
mfu = gf.MeshFem(mesh, 3)
mfu.set_classical_fem(elements_degree)
mfd = gf.MeshFem(mesh, 1)
mfd.set_classical_fem(elements_degree)

# %%
mim = gf.MeshIm(mesh, elements_degree*2)
print(mim)
# Out:
# BEGIN MESH_IM
#
#  CONVEX 0 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 1 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 2 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 3 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 4 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 5 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 6 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 7 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 8 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 9 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 10 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 11 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 12 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 13 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 14 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 15 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 16 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 17 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 18 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 19 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 20 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 21 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 22 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 23 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 24 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 25 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 26 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 27 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 28 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 29 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 30 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 31 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 32 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 33 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 34 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 35 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 36 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 37 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 38 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 39 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 40 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 41 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 42 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 43 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 44 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 45 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 46 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 47 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 48 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 49 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 50 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 51 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 52 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 53 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 54 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 55 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 56 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 57 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 58 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 59 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 60 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 61 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 62 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 63 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 64 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 65 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 66 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 67 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 68 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 69 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 70 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 71 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 72 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 73 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 74 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 75 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 76 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 77 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 78 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
#  CONVEX 79 'IM_PRODUCT(IM_PRODUCT(IM_GAUSS1D(4),IM_GAUSS1D(4)),IM_GAUSS1D(4))'
# END MESH_IM

# %%
rho = 7.874e-06 # kg/mm3
M = gf.asm_mass_matrix(mim, mfu)
M.scale(rho)

# %%
E = 205000.0  # N/mm2
Nu = 0.0
Lambda = E * Nu / ((1 + Nu) * (1 - 2 * Nu))
Mu = E / (2 * (1 + Nu))
Lambdas = np.repeat([Lambda], mfd.nbdof())
Mus = np.repeat(Mu, mfd.nbdof())
K = gf.asm_linear_elasticity(mim, mfu, mfd, Lambdas, Mus)

# %%
A = np.linalg.inv(M.full()) @ K.full()
omega2, vecs = np.linalg.eig(A)

# %%
omega2_sort = np.sort(omega2)
sort_index = np.argsort(omega2)

# %%
print(omega2_sort[:10])
# Out:
# [-1.50397870e-08+0.j -7.06398102e-09+0.j  5.43203467e-09+0.j
#   9.37529503e-09+0.j  1.20241216e-08+0.j  2.66179834e-08+0.j
#   1.02011998e+02+0.j  1.02011998e+02+0.j  7.01499874e+02+0.j
#   7.01499874e+02+0.j]

# %%
f1 = np.sqrt(omega2_sort[6]) / (2.0 * np.pi)
print(f1.real, "Hz")
# Out:
# 1.6074806704480378 Hz

# %%
U = vecs[:, sort_index[6]].real
mfu.export_to_vtk("mfu.vtk", "ascii", mfu, U, "U")

# %%
m = pv.read("mfu.vtk")
m.plot(scalars="U", show_edges="True", jupyter_backend="static")
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F23A11548B0>

# %%
w = m.warp_by_vector("U", factor=10000.0)
w.plot(scalars="U", show_edges="True", jupyter_backend="static")
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F23A1154880>

# %%
L = 10000.0
clambda = 4.730
b = 1000.0
h = 1000.0
A = b * h
I = b * h ** 3 / 12.0
f = 1.0 / (2.0 * np.pi) * clambda ** 2 / L ** 2 * np.sqrt((E * I) / (rho * A))
print("f = ", f, "Hz")
# Out:
# f =  1.6585593440339137 Hz

# %%
from scipy import io
from scipy.sparse.linalg import eigsh
import matplotlib.pyplot as plt

# %%
K.save("mm", "K.mtx")
M.save("mm", "M.mtx")

# %%
pk = io.mmread("K.mtx")
pm = io.mmread("M.mtx")

fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle("K and M Matrix profiles")
ax1.spy(pk, markersize=0.01)
ax1.set_title("K Matrix")
ax2.spy(pm, markersize=0.01)
ax2.set_title("M Matrix")
plt.show(block=True)

# %%
omega2, vecs = eigsh(A=pk, M=pm, k=10, sigma=-0.0001, which="LA")

# %%
print(omega2)
# Out:
# [-8.48753897e-11 -3.88393129e-11 -1.73224698e-11  3.93524109e-11
#   1.10492169e-10  1.60918619e-10  1.02011998e+02  1.02011999e+02
#   7.01499874e+02  7.01499963e+02]

# %%
f1 = np.sqrt(omega2[6]) / (2.0 * np.pi)
print(f1.real, "Hz")
# Out:
# 1.6074806705320723 Hz
